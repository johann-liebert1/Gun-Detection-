# %%
import pandas as pd

# %%
df=pd.read_csv("Book1.csv",sep=',')

# %%
df.head()
# Out:
#   Last Name,First Name,Student ID,CAMPUS ID,L1,L2,L3,L4,L5,L6,L7,L8,L9,L10,LPQ1,Fin End Se,End Sem,CM,SM,FSM,Cumulative Marks,
# 0  Mishra,Vedansh,00000030805,202210101330001,10,...
# 1  Singh,Shikhar,00000029179,202210101330002,9,9,...
# 2  Singh,Harsh,00000029581,202210101330003,9,9,9,...
# 3  Singh,Abhay Pratap,00000030440,202210101330004...
# 4  Singh,Abhay Pratap,00000031124,202210101330005...
